# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
import scipy.stats as st
from torch.optim import Adam
import argparse
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split


from collections import defaultdict
import pandas as pd
import numpy as np
import scanpy as scanpy

def _str2bool(v):
    return v.lower() in ("yes", "y", "true", "t", "1")

# %%
# dataloader.py에 있는 Custom_data()를 h5ad가 아니라 
# 이미 load된 AnnData 객체를 받아 처리하는 버전으로 하나 추가하면 됩니다.
def Custom_data_from_loaded(data, args):
    # 1. 라벨 매핑 정의
    id_dict = {
        'normal': 0,
        'COVID-19': 1,
        'hypertrophic cardiomyopathy':1,
        'dilated cardiomyopathy':2,

        'Healthy_stone_donor':0,
        'Healthy_living_donor':0,
        'CKD':1,
        'AKI':2
    }

    # 2. 환자 ID, 라벨, 셀 타입 정보 추출
    patient_id = data.obs['patient'] if 'patient' in data.obs else data.obs['donor_id']
    labels = data.obs['disease__ontology_label']  if 'disease__ontology_label' in data.obs else data.obs['disease_category']

    # cell_type = data.obs[args.cell_type_annotation]
    # 🔧 여기 수정: args.cell_type_annotation 우선 사용
    anno_col = getattr(args, "cell_type_annotation", "singler_annotation")
    if anno_col in data.obs:
        cell_type = data.obs[anno_col].astype("string").fillna("Unknown")
        print("cell type : ", cell_type)
    else:
        print(f"⚠️ '{anno_col}' 컬럼이 없어 'manual_annotation'로 대체합니다.")
        cell_type = data.obs['singler_annotation'].astype("string").fillna("Unknown")
    
    # cell_type = data.obs['manual_annotation']
    # cell_type = data.obs['singler_annotation']

    # pd.set_option('display.max_seq_items', None)  # 유니크 항목 출력 제한 해제
    # print("cell type annotation : ",cell_type)
    # print("✅ [DEBUG] manual_annotation 유니크값:", list(cell_type.unique()))
    # print("✅ [DEBUG] manual_annotation isna sum:", cell_type.isna().sum())
    # print("✅ [DEBUG] manual_annotation dtype:", cell_type.dtype)

    # print("✅ [DEBUG] NaN 위치들:")
    # print(cell_type[cell_type.isna()])

    # 3. expression 데이터 선택
    if args.pca:
        origin = data.obsm['X_pca']
    else:
        origin = data.X.toarray() if not isinstance(data.X, np.ndarray) else data.X

    # 4. 라벨을 숫자로 변환
    labels_ = np.array(labels.map(id_dict))

    # 5. 환자별 인덱스를 구성
    l_dict = {}
    indices = np.arange(origin.shape[0])
    p_ids = sorted(set(patient_id))
    p_idx = []
    
    
    # 환자 단위로 셀을 모아,
    # 다라벨이면 라벨별로 쪼개어 인덱스 묶음을 만들고,
    # 단일 라벨이면 환자 전체 셀 묶음을 만들어,
    # 이 묶음(=후속 단계에서 bag으로 쓰일 원천 집합) 들을 p_idx 리스트에 차곡차곡 쌓는 로직입니다.

    for i in p_ids: # 모든 환자 ID(p_ids)를 하나씩 순회합니다. 여기서 반복 변수 i는 “현재 환자 ID”입니다.
        idx = indices[patient_id == i] # 현재 환자 i에 속하는 셀들의 전체 인덱스를 뽑습니다.
                                        # patient_id == i가 불리언 마스크(길이 = 전체 셀 수)를 만들고,
                                        # 그 마스크로 indices를 필터링해 해당 환자의 셀 인덱스 배열 idx를 얻습니다.
        if len(set(labels_[idx])) > 1:   # one patient with more than one labels # 이 환자 i의 셀들(idx)에 서로 다른 라벨이 2개 이상 있는지 확인합니다.
            for ii in sorted(set(labels_[idx])): # 환자 i에서 라벨별로 나누어 처리하기 위해, 유일 라벨들을 정렬해서 하나씩 순회합니다. # 예: 라벨 집합이 {0, 1, -1}이라면 -1, 0, 1 순으로 돌아요.
                if ii > -1: # 유효 라벨만 사용합니다. # ex: 0,1,2
                    iidx = idx[labels_[idx] == ii] # 현재 라벨 ii에 해당하는 부분 셀 인덱스 묶음을 만듭니다.
                                                    # labels_[idx] == ii는 길이 len(idx)인 불리언 마스크,
                                                    # 그걸로 idx를 다시 필터링하면 “환자 i & 라벨 ii” 조건을 만족하는 셀 인덱스 배열 iidx가 됩니다.
                    tt_idx = iidx
                    # ★ 개수 체크(최소 셀 수 조건) 없이 전부 추가하기 위해 이 코드는 주석처리 하자
                    # if len(tt_idx) < 500:  # exclude the sample with the number of cells fewer than 500
                    #     continue
                    p_idx.append(tt_idx) # 라벨별로 쪼갠 인덱스 묶음(iidx) 을 p_idx 리스트에 넣습니다.
                                            # 나중 단계(샘플링/로더/모델)에서 이 묶음을 “한 bag의 원천 재료”로 사용합니다.
                                            # 다라벨 환자는 라벨 개수만큼 여러 묶음이 생깁니다.
                    l_dict[labels_[iidx[0]]] = l_dict.get(labels_[iidx[0]], 0) + 1     # p_idx에 하나의 인덱스 묶음(= 환자-라벨 그룹)을 추가할 때, 그 묶음의 라벨을 key로 해서 l_dict 값을 +1 증가

        else: # 이 분기는 단일 라벨 환자인 경우(= 유일 라벨 개수 == 1)입니다.
            if labels_[idx[0]] > -1: # 그 단일 라벨이 유효한지 확인합니다. (여기서도 -1은 제외)
                                    # 주의: idx가 비어있다면 idx[0]에서 에러가 납니다. 일반적으로 환자에 최소 1개 셀이 있다고 가정합니다.
                tt_idx = idx
                # ★ 개수 체크(최소 셀 수 조건) 없이 전부 추가하기 위해 이 코드는 주석처리 하자
                # if len(tt_idx) < 500:  # exclude the sample with the number of cells fewer than 500
                #     continue
                p_idx.append(tt_idx) # 단일 라벨 환자는 환자 전체 셀 인덱스 묶음(idx)을 그대로 p_idx에 추가합니다.
                                     # 이렇게 하면, 단일 라벨 환자는 묶음 1개, 다라벨 환자는 라벨 수만큼 여러 묶음이 들어가게 됩니다.
                l_dict[labels_[idx[0]]] = l_dict.get(labels_[idx[0]], 0) + 1     # p_idx에 하나의 인덱스 묶음(= 환자-라벨 그룹)을 추가할 때, 그 묶음의 라벨을 key로 해서 l_dict 값을 +1 증가

    print("라벨별 그룹 개수",l_dict) # 다라벨 환자는 라벨마다 여러 묶음으로 잡히니 그만큼 여러 번 카운트됩니다.
    # ex) 라벨별 그룹 개수 {1: 3, 2: 2, 0: 4} # https://chatgpt.com/s/t_689d6521e6088191bb414a646b947ee5 

    # 6. numpy 기반으로 반환
    return p_idx, labels_, np.array(cell_type), np.array(patient_id), origin

# %%
import argparse

parser = argparse.ArgumentParser()

parser.add_argument('--seed', type=int, default=240)
parser.add_argument('--batch_size', type=int, default=16)
parser.add_argument('--learning_rate', type=float, default=3e-3)
parser.add_argument('--weight_decay', type=float, default=1e-4)
parser.add_argument('--epochs', type=int, default=100)
parser.add_argument("--task", type=str, default="severity")
parser.add_argument('--emb_dim', type=int, default=128)  # embedding dim
parser.add_argument('--h_dim', type=int, default=128)  # hidden dim of the model
parser.add_argument('--dropout', type=float, default=0.3)  # dropout
parser.add_argument('--layers', type=int, default=1)
parser.add_argument('--heads', type=int, default=8)
parser.add_argument("--train_sample_cells", type=int, default=500,
                    help="number of cells in one sample in train dataset") # 학습 시 각 환자 샘플에서 500개 세포를 랜덤 선택
parser.add_argument("--test_sample_cells", type=int, default=500,
                    help="number of cells in one sample in test dataset") # 테스트 시에도 동일하게 500개 세포 선택
parser.add_argument("--train_num_sample", type=int, default=20,
                    help="number of sampled data points in train dataset") # 한 명의 환자에서 500개의 세포를 20번 샘플링하여 20개의 bag 생성
parser.add_argument("--test_num_sample", type=int, default=100,
                    help="number of sampled data points in test dataset") # 테스트도 같은 방식으로 100개의 bag 생성
parser.add_argument('--model', type=str, default='Transformer')
parser.add_argument('--dataset', type=str, default=None)
parser.add_argument('--inter_only', type=_str2bool, default=False) # mixup된 샘플만 학습에 사용할지 여부
parser.add_argument('--same_pheno', type=int, default=0) # 같은 클래스끼리 mixup할지, 다른 클래스끼리 할지
parser.add_argument('--augment_num', type=int, default=0) # Mixup된 새로운 가짜 샘플을 몇 개 생성할지
parser.add_argument('--alpha', type=float, default=1.0) # mixup의 비율 (Beta 분포 파라미터)
parser.add_argument('--repeat', type=int, default=3)
parser.add_argument('--all', type=int, default=1)
parser.add_argument('--min_size', type=int, default=6000)
parser.add_argument('--n_splits', type=int, default=5)
parser.add_argument('--pca', type=_str2bool, default=False)
parser.add_argument('--mix_type', type=int, default=1)
parser.add_argument('--norm_first', type=_str2bool, default=False)
parser.add_argument('--warmup', type=_str2bool, default=False)
parser.add_argument('--top_k', type=int, default=1)

args, unknown = parser.parse_known_args()

# %%
from IPython.display import display
import pandas as pd
import numpy as np

# pandas 출력 무제한
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# numpy 출력 무제한
np.set_printoptions(threshold=np.inf)

# %%
for repeat in range(1):
    fold_aucs, accuracy, cms, recalls, precisions = [], [], [], [], []
    iter_count = 0
    for fold in range(1):
        print(f"🔁 Repeat {repeat}, Fold {fold}")
        train_path = f"/data/project/kim89/0804_data/repeat_{repeat}/fold_{fold}_train.h5ad"
        test_path = f"/data/project/kim89/0804_data/repeat_{repeat}/fold_{fold}_test.h5ad"

        train_data = scanpy.read_h5ad(train_path)
        test_data = scanpy.read_h5ad(test_path)

        train_p_index, train_labels, train_cell_type, patient_id, train_origin = Custom_data_from_loaded(train_data, args)
        test_p_index, test_labels, test_cell_type, test_patient_id, test_origin = Custom_data_from_loaded(test_data, args)

        # labels_ = train_labels
        labels_ = np.concatenate([train_labels, test_labels])

        print(f"🔍 Split #{iter_count + 1}")
        print(f"  → train_p_index 환자 수: {len(train_p_index)}")
        print(f"  → test_p_index 환자 수: {len(test_p_index)}")

        # 실제 환자 ID로 보기
        train_ids = [patient_id[idx[0]] for idx in train_p_index]
        test_ids = [test_patient_id[idx[0]] for idx in test_p_index]
        print(f"  → train 환자 ID: {train_ids}")
        print(f"  → test  환자 ID: {test_ids}")

        # 각 환자의 ID와 label 함께 출력
        print("  → train 환자 ID 및 라벨:")
        for idxs in train_p_index:
            idx = idxs[0]
            print(f"    ID: {patient_id[idx]}, Label: {train_labels[idx]}")

        print("  → test 환자 ID 및 라벨:")
        for idxs in test_p_index:
            idx = idxs[0]
            print(f"    ID: {test_patient_id[idx]}, Label: {test_labels[idx]}")
# Out:
# 🔁 Repeat 0, Fold 0
# cell type :  CATTAAGGATAT_COVID19_Participant13         Epithelial_cells
# GTAGAAGGGGGG_COVID19_Participant13                Platelets
# ATTAAGAGGTAG_COVID19_Participant13         Epithelial_cells
# AGATATGACAAG_COVID19_Participant13         Epithelial_cells
# CTTGTAACAAAT_COVID19_Participant13         Epithelial_cells
# CACTATTTCTCT_COVID19_Participant13            Keratinocytes
# CAAAATAGTCTA_COVID19_Participant13               Macrophage
# GTTGTAATGGTT_COVID19_Participant13         Epithelial_cells
# TACATAGAATAG_COVID19_Participant13                   B_cell
# CATAGCTTATGT_COVID19_Participant13         Epithelial_cells
# AACCAAGAAGTG_COVID19_Participant13              Neutrophils
# GAACATAAGATT_COVID19_Participant13         Epithelial_cells
# TCCGCACATAAA_COVID19_Participant13         Epithelial_cells
# ATTATCGTCTTC_COVID19_Participant13                       DC
# ATGAGAGCCAAA_COVID19_Participant13                 Monocyte
# CATAGTTGTCGA_COVID19_Participant13         Epithelial_cells
# GCACCGCATCAA_COVID19_Participant13         Epithelial_cells
# CATAATCATTCA_COVID19_Participant13         Epithelial_cells
# AGTAAGATCGCA_COVID19_Participant13         Epithelial_cells
# TTACACGCCGAC_COVID19_Participant13               Macrophage
# GTCATAGAGATT_COVID19_Participant13            Keratinocytes
# AAGAGACTTTGG_COVID19_Participant13         Epithelial_cells
# AACCTATACTGA_COVID19_Participant13              Neutrophils
# TGGATATATTTT_COVID19_Participant13         Epithelial_cells
# GGACAGGGTGTG_COVID19_Participant13                  T_cells
# CTTAGCGGGCTG_COVID19_Participant13                  T_cells
# GCTATCTTCAGA_COVID19_Participant13         Epithelial_cells
# TACCTGTCCTGG_COVID19_Participant13               Macrophage
# GTGATATATGAA_COVID19_Participant13                  T_cells
# TGACAATGGTGC_COVID19_Participant13         Epithelial_cells
# TGTTTCGTTCAA_COVID19_Participant13         Epithelial_cells
# GATCGCCCAACT_COVID19_Participant13         Epithelial_cells
# GGGAAGAGGGTT_COVID19_Participant13              Neutrophils
# GAGGGTCGGGTG_COVID19_Participant13         Epithelial_cells
# GCACTATTTAAC_COVID19_Participant13         Epithelial_cells
# CCCTATTCCGAC_COVID19_Participant13               Macrophage
# TATCCCAAGCAG_COVID19_Participant13            Keratinocytes
# ATCCAACAGGTG_COVID19_Participant13            Keratinocytes
# ATCAGCTTATCT_COVID19_Participant13                  T_cells
# CTGAATCCGAAC_COVID19_Participant13         Epithelial_cells
# CACCCCGGACAT_COVID19_Participant13         Epithelial_cells
# CGTGAATATCCA_COVID19_Participant13         Epithelial_cells
# CATTACTCCTTA_COVID19_Participant13                  T_cells
# CACCTCGGAGCA_COVID19_Participant13                  NK_cell
# GTACCTAAACAT_COVID19_Participant13                       DC
# ATAGCGGTTTGA_COVID19_Participant13         Epithelial_cells
# TAAGTAAATGGT_COVID19_Participant13                HSC_CD34+
# TTAATAAGTCAA_COVID19_Participant13         Epithelial_cells
# AGGTCGTCAATG_COVID19_Participant13                  NK_cell
# ATTATTTGCCAG_COVID19_Participant13         Epithelial_cells
# TTGATTAGTGGG_COVID19_Participant13        Tissue_stem_cells
# CAACACTCTATG_COVID19_Participant13         Epithelial_cells
# ATCTCGATTTAT_COVID19_Participant13               Macrophage
# AGTTAGTTTTAG_COVID19_Participant13         Epithelial_cells
# CAGGGGATTGCA_COVID19_Participant13         Epithelial_cells
# GTACAAACCAGA_COVID19_Participant13         Epithelial_cells
# TCTTTGACCGAC_COVID19_Participant13              Neutrophils
# GATTGTCTCGCG_COVID19_Participant13         Epithelial_cells
# AATCCTTTAATA_COVID19_Participant13     Embryonic_stem_cells
# TCGCGAGTCGCC_COVID19_Participant13         Epithelial_cells
# CTTCAGGACGCT_COVID19_Participant13         Epithelial_cells
# CTACAACCTAAA_COVID19_Participant13         Epithelial_cells
# CGACTCAATATC_COVID19_Participant13         Epithelial_cells
# AGGGAATAGGGA_COVID19_Participant13            Keratinocytes
# CGTACTTATTTC_COVID19_Participant13                  NK_cell
# CGATCGCTGTTC_COVID19_Participant13         Epithelial_cells
# CAAGATTAGTAA_COVID19_Participant13         Epithelial_cells
# GTCACGGATCAC_COVID19_Participant13     Embryonic_stem_cells
# ACGATCTCTTAG_COVID19_Participant13            Keratinocytes
# GCCTACATCCGA_COVID19_Participant13                  NK_cell
# TCTAATCGTCCT_COVID19_Participant13               Macrophage
# AAGCCTTGTTCC_COVID19_Participant13         Epithelial_cells
# CAACCAAACACT_COVID19_Participant13               Macrophage
# AGACGAAAAGAT_COVID19_Participant13         Epithelial_cells
# GAGGCGTCGCAC_COVID19_Participant13                 Monocyte
# GCTTGCGATACT_COVID19_Participant13         Epithelial_cells
# CTGACCTGCCTG_COVID19_Participant13         Epithelial_cells
# GTATTATCGGCT_COVID19_Participant13               Macrophage
# ACCTGACCGTTC_COVID19_Participant13         Epithelial_cells
# CCTGATATAACC_COVID19_Participant13            Keratinocytes
# CTAATGTCGTGT_COVID19_Participant13         Epithelial_cells
# CTCTCTCACTTG_COVID19_Participant13         Epithelial_cells
# ATTATGGCCTGC_COVID19_Participant13              Neutrophils
# AGATCTTACAAC_COVID19_Participant13         Epithelial_cells
# TAGGTATTAACT_COVID19_Participant13               Macrophage
# CACACTATGAAG_COVID19_Participant13               HSC_-G-CSF
# GACTCTTATTTG_COVID19_Participant13               Macrophage
# AATACGGAAATA_COVID19_Participant13                       DC
# TCAATGATCTCT_COVID19_Participant13         Epithelial_cells
# GAAGCTCTCCAT_COVID19_Participant13         Epithelial_cells
# GTATTTACAGAA_COVID19_Participant13            Keratinocytes
# CCGCTTATATGT_COVID19_Participant13         Epithelial_cells
# CTTCGATACAGC_COVID19_Participant13               Macrophage
# ATATCCCGTATA_COVID19_Participant13                  T_cells
# TATTCATAATTT_COVID19_Participant13         Epithelial_cells
# GTAACCTTGGTT_COVID19_Participant13                 Monocyte
# TCCCGCCCAAGG_COVID19_Participant13               Macrophage
# ACCAGATCTATT_COVID19_Participant13                  Neurons
# CGAACCTGCGAA_COVID19_Participant13                 Monocyte
# ACTATGGCAATC_COVID19_Participant13         Epithelial_cells
# AGCACTGATACC_COVID19_Participant13         Epithelial_cells
# TCTTTGTTACGT_COVID19_Participant13               Macrophage
# CCTTAATGGAGC_COVID19_Participant13         Epithelial_cells
# ACTACGGTATCC_COVID19_Participant13         Epithelial_cells
# TATATGCCCACT_COVID19_Participant13         Epithelial_cells
# CTCAGACTCACT_COVID19_Participant13         Epithelial_cells
# GCCCCAGGTCTT_COVID19_Participant13            Keratinocytes
# GTACCCGTGTTG_COVID19_Participant13         Epithelial_cells
# TGCTCGCTCCGG_COVID19_Participant13         Epithelial_cells
# CAGATATTTCGT_COVID19_Participant13                  T_cells
# GGTTTTTCACTA_COVID19_Participant13         Epithelial_cells
# TTACGAGCATCA_COVID19_Participant13              Neutrophils
# TCTATGGCACTG_COVID19_Participant13                       BM
# ACTGAAATTTGT_COVID19_Participant13         Epithelial_cells
# TCCGGAGATTCC_COVID19_Participant13             Erythroblast
# ATGCAAGAAACC_COVID19_Participant13         Epithelial_cells
# ATAACTGTCCAC_COVID19_Participant13            Keratinocytes
# CCTTGAGAATCC_COVID19_Participant13         Epithelial_cells
# GTATAATTGGCA_COVID19_Participant13                  NK_cell
# AACTCCCAAAGA_COVID19_Participant13         Epithelial_cells
# TAGTAAAACACG_COVID19_Participant13              Neutrophils
# CGTTAATGTTCG_COVID19_Participant13         Epithelial_cells
# AAATACCAACGA_COVID19_Participant13              Neutrophils
# CAAGGCATCCAT_COVID19_Participant13         Epithelial_cells
# CGTTCGACACCC_COVID19_Participant13         Epithelial_cells
# AGTGGTATACAG_COVID19_Participant13         Epithelial_cells
# TACGCACATGCT_COVID19_Participant13                  T_cells
# AAACATGGAATC_COVID19_Participant13                  T_cells
# CATCGACTACCA_COVID19_Participant13         Epithelial_cells
# CTCCCTTCCAGT_COVID19_Participant13              Neutrophils
# CATTTACTAAAT_COVID19_Participant13         Epithelial_cells
# GACGGCCGTGCT_COVID19_Participant13                 Monocyte
# GTTAGTCACCAG_COVID19_Participant13                       DC
# AGATACATCGTT_COVID19_Participant13              Neutrophils
# GCGGGTGGGCTT_COVID19_Participant13                  NK_cell
# TGATTCCCGGTT_COVID19_Participant13         Epithelial_cells
# CTCATAAGATTG_COVID19_Participant13                  T_cells
# CGCCCCGGACAA_COVID19_Participant13         Epithelial_cells
# CATCTCTTGCTT_COVID19_Participant13              Neutrophils
# TTAACGTAGCCA_COVID19_Participant13                  NK_cell
# TAAATAAGTAAA_COVID19_Participant13         Epithelial_cells
# AAATAGATAGCT_COVID19_Participant13         Epithelial_cells
# AAATATAACATA_COVID19_Participant13         Epithelial_cells
# GGACGCGGGAAT_COVID19_Participant13                  T_cells
# AGCATTCGTTAA_COVID19_Participant13         Epithelial_cells
# CAACTCGACCCT_COVID19_Participant13         Epithelial_cells
# CTGATAAATGCA_COVID19_Participant13         Epithelial_cells
# TAACAGTCAGCA_COVID19_Participant13         Epithelial_cells
# CAAGATTTACAT_COVID19_Participant13         Epithelial_cells
# CTTCGCTTATTT_COVID19_Participant13         Epithelial_cells
# CGAGACAAGTCA_COVID19_Participant13         Epithelial_cells
# TGCCCCACGCGT_COVID19_Participant13         Epithelial_cells
# ACAAAGGTTTCC_COVID19_Participant13         Epithelial_cells
# ACGGACTTCCTT_COVID19_Participant13              Neutrophils
# GATAGCCTGCTC_COVID19_Participant13              Fibroblasts
# CTATTTGTGATG_COVID19_Participant13               Macrophage
# CTAGCATACACC_COVID19_Participant13                  T_cells
# ACCGTTATTGCT_COVID19_Participant13         Epithelial_cells
# ACTTCCATTCGA_COVID19_Participant13         Epithelial_cells
# CCCTTTCGAGTT_COVID19_Participant13               Macrophage
# CAGCTTACAATT_COVID19_Participant13                 Monocyte
# TGGAGCGGCTCC_COVID19_Participant13                       DC
# GATCAAAAAGTT_COVID19_Participant13         Epithelial_cells
# AAGGATAACATG_COVID19_Participant13                  T_cells
# CGTATAACTCGT_COVID19_Participant13            Keratinocytes
# CGAGGATAGAGT_COVID19_Participant13         Epithelial_cells
# CGGGTCTCCAAC_COVID19_Participant13                iPS_cells
# AATGCACTTTCT_COVID19_Participant13         Epithelial_cells
# CTAGCGCCGACT_COVID19_Participant13              Neutrophils
# GGACACCTGCAA_COVID19_Participant13                       DC
# ACCAATAGTCAT_COVID19_Participant13         Epithelial_cells
# CCACATGACTGT_COVID19_Participant13         Epithelial_cells
# TTGCCCTCAGAC_COVID19_Participant13              Hepatocytes
# GACGAACTCCAC_COVID19_Participant13                Platelets
# CATGAACTATGA_COVID19_Participant13                  T_cells
# TGATCATAGAAT_COVID19_Participant13                  NK_cell
# ACATTTCAACTT_COVID19_Participant13                  NK_cell
# GGATCGGAGGCA_COVID19_Participant13         Epithelial_cells
# TATCGTTATAGT_COVID19_Participant13                      CMP
# GACCTAGTATAA_COVID19_Participant13                 Monocyte
# GGACTACCGCTA_COVID19_Participant13         Epithelial_cells
# GGTACTTTGTAA_COVID19_Participant13         Epithelial_cells
# AGTACATGCTGA_COVID19_Participant13               HSC_-G-CSF
# AAGGAATTTGAT_COVID19_Participant13         Epithelial_cells
# CGAGCATATCGA_COVID19_Participant13                  NK_cell
# GCTATTAGATGC_COVID19_Participant13         Epithelial_cells
# ATAGACTCATAG_COVID19_Participant13         Epithelial_cells
# AAAATCATTTAA_COVID19_Participant13         Epithelial_cells
# AGGAAATAACCC_COVID19_Participant13                  NK_cell
# TAATCTCCCAGT_COVID19_Participant13         Epithelial_cells
# TTAAACGTCCCA_COVID19_Participant13         Epithelial_cells
# ATCGGGATGGTT_COVID19_Participant13                  NK_cell
# CGATGATTACGC_COVID19_Participant13         Epithelial_cells
# GTTCCCTGTTCA_COVID19_Participant13            Keratinocytes
# CAATCACCATCC_COVID19_Participant13            Keratinocytes
# AATAGAAGACTC_COVID19_Participant13              Gametocytes
# GCACGCGGGGCT_COVID19_Participant13               Macrophage
# TAAATACACTCC_COVID19_Participant13                  NK_cell
# CGAATTCTCAAC_COVID19_Participant13        Tissue_stem_cells
# TATCTTGAATCA_COVID19_Participant13             Chondrocytes
# CCTAGGACGGAG_COVID19_Participant13                      CMP
# ATCTGGCGAACC_COVID19_Participant13            Keratinocytes
# TGCAGCTCATGA_COVID19_Participant13                 Monocyte
# CAACGTGCGTTA_COVID19_Participant13              Neutrophils
# ATAAACGTTAGC_COVID19_Participant13                       BM
# GGATGATAAAAT_COVID19_Participant13              Neutrophils
# TAGGTCGCCGAT_COVID19_Participant13                 Monocyte
# TCTTAAAGCTGG_COVID19_Participant13               Macrophage
# TACTTTTCTAGC_COVID19_Participant13         Epithelial_cells
# GGAGGGGACATA_COVID19_Participant13                  T_cells
# AAGTTATGCTGA_COVID19_Participant13         Epithelial_cells
# TTGACTTGGCGC_COVID19_Participant13         Epithelial_cells
# GAGCATGTAAGA_COVID19_Participant13         Epithelial_cells
# GTACCTCTTCTA_COVID19_Participant13         Epithelial_cells
# TAGCACAAGTAA_COVID19_Participant13         Epithelial_cells
# CTCTAGATATGC_COVID19_Participant13         Epithelial_cells
# CGGCTAGTCCCT_COVID19_Participant13         Epithelial_cells
# GATCTTCGCAGA_COVID19_Participant13         Epithelial_cells
# TGTGGGTGGCAA_COVID19_Participant13                  T_cells
# CCAAACCTACAG_COVID19_Participant13                  T_cells
# TGATGAGCCGGA_COVID19_Participant13         Epithelial_cells
# TAAGCCAAAAAC_COVID19_Participant13              Neutrophils
# CTATGTGATCAA_COVID19_Participant13         Epithelial_cells
# CTTCAAGCAAAG_COVID19_Participant13         Epithelial_cells
# ATAATCCAAATG_COVID19_Participant13         Epithelial_cells
# CAGCAGGGGTAG_COVID19_Participant13                  NK_cell
# GATATCAGCCCA_COVID19_Participant13                  NK_cell
# ATCGCCATTACC_COVID19_Participant13         Epithelial_cells
# AAGCCAACACAC_COVID19_Participant13         Epithelial_cells
# TCTTCGTCTGTT_COVID19_Participant13         Epithelial_cells
# CGACAAAATTAC_COVID19_Participant13         Epithelial_cells
# CTGTATCAGCTC_COVID19_Participant13                HSC_CD34+
# CCAATTTGCATA_COVID19_Participant13         Epithelial_cells
# GAATCGCTTGAT_COVID19_Participant13         Epithelial_cells
# GTAAACTCAAGT_COVID19_Participant13         Epithelial_cells
# GAGACTAATAAA_COVID19_Participant13         Epithelial_cells
# CATTCTAGCACT_COVID19_Participant13         Epithelial_cells
# AAGCCAAATTCC_COVID19_Participant13         Epithelial_cells
# CTAGCACATCTG_COVID19_Participant13                  T_cells
# GTAAGTCCTTCC_COVID19_Participant13                  NK_cell
# CTTGATAATCAC_COVID19_Participant13        Endothelial_cells
# GTCCAATTGTTC_COVID19_Participant13                  NK_cell
# TGACGTAATGCA_COVID19_Participant13         Epithelial_cells
# AAGCCTGGGTCC_COVID19_Participant13         Epithelial_cells
# AACATGATTTCT_COVID19_Participant13            Keratinocytes
# GGGTACATTTCA_COVID19_Participant13                  NK_cell
# CCCTCCATGCTT_COVID19_Participant13         Epithelial_cells
# AAGCTGGAATGA_COVID19_Participant13         Epithelial_cells
# TACCGTATCACA_COVID19_Participant13         Epithelial_cells
# GTAATAATCCCA_COVID19_Participant13         Pre-B_cell_CD34-
# CTTTCTCATGTC_COVID19_Participant13                 Monocyte
# CCGGCTTAAGGC_COVID19_Participant13         Epithelial_cells
# CGTCTACACCGT_COVID19_Participant13         Epithelial_cells
# CTAACTGAAGAT_COVID19_Participant13         Pre-B_cell_CD34-
# CCGTTAGACCTT_COVID19_Participant13                  NK_cell
# GCATGATCGCGG_COVID19_Participant13               Macrophage
# TGTCCCACGATA_COVID19_Participant13         Epithelial_cells
# GGTCAGGGAGTT_COVID19_Participant13         Epithelial_cells
# TCCGTCCGCAAA_COVID19_Participant13         Epithelial_cells
# GAACCACTCTTG_COVID19_Participant13         Epithelial_cells
# GATACTAAATAT_COVID19_Participant13         Epithelial_cells
# AAGTGGCCCCAT_COVID19_Participant13               HSC_-G-CSF
# CGGCTTCTACAT_COVID19_Participant13            Keratinocytes
# ATTCTATAACGA_COVID19_Participant13         Epithelial_cells
# GCTGCTCAGCCA_COVID19_Participant13            Keratinocytes
# CTCTAGCAGATT_COVID19_Participant13              Neutrophils
# GATTACTCAGTA_COVID19_Participant13         Epithelial_cells
# TCCACCATTAAG_COVID19_Participant13               Macrophage
# TTCTTACGTTTT_COVID19_Participant13                 Monocyte
# AACTATATCAAC_COVID19_Participant13                  T_cells
# ATCCTCCTTAAC_COVID19_Participant13            Keratinocytes
# AATTTATCGTTC_COVID19_Participant13            Keratinocytes
# GAATGCATCATC_COVID19_Participant13                       DC
# AATGAGGCAATC_COVID19_Participant13         Epithelial_cells
# CTGACTTCCGTT_COVID19_Participant13         Epithelial_cells
# AAGGAGGGCGAT_COVID19_Participant13               Macrophage
# CTCGATGAACGA_COVID19_Participant13         Epithelial_cells
# GAGCAATATTAT_COVID19_Participant13         Epithelial_cells
# GAACTAAACTTA_COVID19_Participant13             Erythroblast
# TTGGACATTTAC_COVID19_Participant13                   B_cell
# TTCTGTGGCACG_COVID19_Participant13         Epithelial_cells
# AACCCAGGCGCA_COVID19_Participant13         Epithelial_cells
# TGAGTTCATAGC_COVID19_Participant13                  Neurons
# CCCCTTGACTTC_COVID19_Participant13                 Monocyte
# ACAAGGGTATTC_COVID19_Participant13         Epithelial_cells
# GCCTCCACGACA_COVID19_Participant13                  T_cells
# TCCGATGTTACC_COVID19_Participant13                  NK_cell
# GTCGAGTGTAGG_COVID19_Participant13         Epithelial_cells
# CCAGAGTGGGCA_COVID19_Participant13                  NK_cell
# GGGCAGCTACCA_COVID19_Participant13         Epithelial_cells
# AGATTACTGACT_COVID19_Participant13                  NK_cell
# ATGATTACGGTA_COVID19_Participant13                  T_cells
# ACTAGTCAGACT_COVID19_Participant13         Epithelial_cells
# CCAATCGCGACA_COVID19_Participant13         Epithelial_cells
# AAGCCGTCGACC_COVID19_Participant13                  T_cells
# AGACTATCCCAA_COVID19_Participant13                       DC
# TGTAATGTTCCG_COVID19_Participant13                Myelocyte
# TTTTTCCGGCTT_COVID19_Participant13         Epithelial_cells
# CAAGAGTTTGTA_COVID19_Participant13               Macrophage
# CCGTTCTGTGAA_COVID19_Participant13         Epithelial_cells
# AGGACATCTTTC_COVID19_Participant13                  T_cells
# GAGGTTTACGTG_COVID19_Participant13            Keratinocytes
# AGTGGAGTATGA_COVID19_Participant13                  T_cells
# CTATTAAGCATC_COVID19_Participant13                  T_cells
# CACGGGGCATGT_COVID19_Participant13         Epithelial_cells
# ATAGTGCGATGA_COVID19_Participant13         Epithelial_cells
# CCCCGGTTGAGT_COVID19_Participant13                  NK_cell
# TAGATTGGACAT_COVID19_Participant13                  NK_cell
# GACTACCGGAAC_COVID19_Participant13                  NK_cell
# GAGAGACTTGAG_COVID19_Participant13                Astrocyte
# GGTCGGGGGGGT_COVID19_Participant13         Epithelial_cells
# CAACACACCCCA_COVID19_Participant13                  NK_cell
# AGGGGCCACTAT_COVID19_Participant13                  NK_cell
# TCTAGTATGTTT_COVID19_Participant13            Keratinocytes
# ATACTGGGACGC_COVID19_Participant13         Epithelial_cells
# TACCCCATTGTG_COVID19_Participant13                  T_cells
# GTGTATTCTGTA_COVID19_Participant13         Epithelial_cells
# GCCCCCGCCCTC_COVID19_Participant13              Neutrophils
# TGTAGCGGCGGC_COVID19_Participant13                Platelets
# GATAGCTATGCC_COVID19_Participant13         Epithelial_cells
# CATAATTTGGTC_COVID19_Participant13                  NK_cell
# TTTCCAACTGTC_COVID19_Participant13         Epithelial_cells
# CATTATCGTGAA_COVID19_Participant13         Epithelial_cells
# TCTCGTTTCCGT_COVID19_Participant13                  T_cells
# TCTCCCGCCATA_COVID19_Participant13         Epithelial_cells
# GTACATGTATAG_COVID19_Participant13         Epithelial_cells
# CCAGGGCTATAC_COVID19_Participant13                  T_cells
# ACTCATATTACC_COVID19_Participant13         Epithelial_cells
# TTTGCTACTATT_COVID19_Participant13                 Monocyte
# AAGTTATCATTG_COVID19_Participant13         Epithelial_cells
# AATAGCAAGAAG_COVID19_Participant13         Epithelial_cells
# CCCAACTTGCCT_COVID19_Participant13         Epithelial_cells
# ATACACGGGAGA_COVID19_Participant13         Epithelial_cells
# TTCCTTACTTGA_COVID19_Participant13               HSC_-G-CSF
# ATCAATAACTTG_COVID19_Participant13                  NK_cell
# TGACCAAGATTA_COVID19_Participant13     Neuroepithelial_cell
# CTCTTATATAGT_COVID19_Participant13         Epithelial_cells
# TAGGTGGGGGGT_COVID19_Participant13                  T_cells
# TCATGACATTCA_COVID19_Participant13         Epithelial_cells
# CTCTCCCGGGGG_COVID19_Participant13               Macrophage
# CAAGAAGATCTA_COVID19_Participant13               Macrophage
# TAACACACCAGT_COVID19_Participant13                       DC
# GTTCCCATATCT_COVID19_Participant13              Fibroblasts
# CATCATAGAATG_COVID19_Participant13               Macrophage
# TTAAATTGCTGA_COVID19_Participant13               Macrophage
# GAATGGTGGGGG_COVID19_Participant13              Neutrophils
# AGCAAGTTTTTA_COVID19_Participant13                  NK_cell
# AGTGCATAAATG_COVID19_Participant13         Epithelial_cells
# AGCATTGGGGCC_COVID19_Participant13        Tissue_stem_cells
# TTCTACAAGTAG_COVID19_Participant13              Neutrophils
# AAGGGGGGGCAT_COVID19_Participant13         Epithelial_cells
# CAGTCTGTCACT_COVID19_Participant13                  T_cells
# CATGTTATTCGT_COVID19_Participant13         Epithelial_cells
# TCCCATGAGACA_COVID19_Participant13         Epithelial_cells
# GTATGTGATATT_COVID19_Participant13         Epithelial_cells
# CTACTACAGGCG_COVID19_Participant13         Pre-B_cell_CD34-
# ATCCGAGAATTT_COVID19_Participant13               Macrophage
# TCTCCCTACATT_COVID19_Participant13             Erythroblast
# GAATAGGCCAAT_COVID19_Participant13                       DC
# GCATCGGGTCGA_COVID19_Participant13         Epithelial_cells
# GTTTAATTTAGA_COVID19_Participant13         Epithelial_cells
# GTTAAATCAAGG_COVID19_Participant13         Epithelial_cells
# ATTTTGCTTCCT_COVID19_Participant13         Epithelial_cells
# CAATTAGTGTGT_COVID19_Participant13         Pre-B_cell_CD34-
# ATGCGATTAAAA_COVID19_Participant13               Macrophage
# AGCACTAGAAGT_COVID19_Participant13                 Monocyte
# AAGAGAGTTAGG_COVID19_Participant13         Epithelial_cells
# ATTCGACAGACT_COVID19_Participant13         Epithelial_cells
# TTCATCATTGTG_COVID19_Participant13                  T_cells
# TCATATTCGTTT_COVID19_Participant13               Macrophage
# GTTAATGGATTT_COVID19_Participant13                  T_cells
# TGGTATCAATTT_COVID19_Participant13     Embryonic_stem_cells
# AATTACTCATTG_COVID19_Participant13                 Monocyte
# GATAGGGAAAGG_COVID19_Participant13                  NK_cell
# AATGAATGAAAT_COVID19_Participant13                 Monocyte
# CATCTAAGTCCC_COVID19_Participant13         Epithelial_cells
# TGAGATGACTTA_COVID19_Participant13         Epithelial_cells
# TCTCATTATGCT_COVID19_Participant13              Neutrophils
# GTATTCTGGTAC_COVID19_Participant13                 Monocyte
# ATCCATTGTAAG_COVID19_Participant13                 Monocyte
# AAGGTTAATTTT_COVID19_Participant13                  NK_cell
# TGTAGGGGGTTG_COVID19_Participant13         Epithelial_cells
# AGTTTTTCAGGA_COVID19_Participant13                 Monocyte
# AGAGGGTGATCA_COVID19_Participant13         Epithelial_cells
# GTAGTTATCGCT_COVID19_Participant13         Epithelial_cells
# CGAAGTCCCTAC_COVID19_Participant13         Epithelial_cells
# GTCTAAAAAGGG_COVID19_Participant13         Epithelial_cells
# TAGACCCGATTC_COVID19_Participant13         Epithelial_cells
# AATAACCTACCC_COVID19_Participant13        Endothelial_cells
# AGGCTCGTATGC_COVID19_Participant13         Epithelial_cells
# TATTCGAGATCA_COVID19_Participant13                 Monocyte
# CACAATTACTCG_COVID19_Participant13                  NK_cell
# GTAAGAACCGAG_COVID19_Participant13              Neutrophils
# ATTGGATGGGTG_COVID19_Participant13                  T_cells
# AAACAAGCACAT_COVID19_Participant13         Epithelial_cells
# GCTCTCGTGCAC_COVID19_Participant13         Epithelial_cells
# CCATTGTGTCCC_COVID19_Participant13         Epithelial_cells
# CAGTAATGTCTA_COVID19_Participant13         Epithelial_cells
# AACTGCTGTCAT_COVID19_Participant13                  NK_cell
# TCCGAAGGTAAT_COVID19_Participant13                       DC
# ACATTAATATCC_COVID19_Participant13               Macrophage
# CAAAATGAGGTA_COVID19_Participant13                  T_cells
# TTATGATGGGAC_COVID19_Participant13         Epithelial_cells
# TGCAGCTCGAAT_COVID19_Participant13         Epithelial_cells
# CATGTTACATAG_COVID19_Participant13                      CMP
# GCTTTCTACCTT_COVID19_Participant13         Epithelial_cells
# TATCTTAAAGGC_COVID19_Participant13               HSC_-G-CSF
# AACGTTCGCCTG_COVID19_Participant13         Epithelial_cells
# TCAGTGTTCTAT_COVID19_Participant13         Epithelial_cells
# CTCGATTGCGTT_COVID19_Participant13         Epithelial_cells
# AGAATCGAGGGA_COVID19_Participant13              Neutrophils
# TAGCGCATGGCT_COVID19_Participant13         Epithelial_cells
# GAGCACAAATGC_COVID19_Participant13         Epithelial_cells
# CGACGAGTGAAT_COVID19_Participant13                 Monocyte
# CGTTACAATTCT_COVID19_Participant13                  NK_cell
# ACATAGTCTGTA_COVID19_Participant13         Epithelial_cells
# GACTCGCTCTTG_COVID19_Participant13                      CMP
# TCATAATCAATG_COVID19_Participant13         Epithelial_cells
# TTATACATATCG_COVID19_Participant13               Macrophage
# CTTAAATGTTCT_COVID19_Participant13                Astrocyte
# AAGCTTTCGCCA_COVID19_Participant13         Epithelial_cells
# TCGCCCGCTCTT_COVID19_Participant13         Epithelial_cells
# CTGAACGAGAGA_COVID19_Participant13         Epithelial_cells
# AAGTGCTTCACA_COVID19_Participant13                  NK_cell
# ACTCCCGTTCCC_COVID19_Participant13         Epithelial_cells
# CCGTCAGCGGAG_COVID19_Participant13         Epithelial_cells
# CAGTACAATTTA_COVID19_Participant13         Epithelial_cells
# TTCCCGTATGGC_COVID19_Participant13         Epithelial_cells
# ATAATTTTAGGT_COVID19_Participant13              Neutrophils
# CGACAATAATTA_COVID19_Participant13         Epithelial_cells
# GCCTATAACATT_COVID19_Participant13                  NK_cell
# GGGTGGTACATT_COVID19_Participant13                  NK_cell
# GATTGCATTAGT_COVID19_Participant13         Epithelial_cells
# TATAAACCATCC_COVID19_Participant13                  T_cells
# TACTCCGATTAC_COVID19_Participant13                  NK_cell
# AAGCAGGTACAC_COVID19_Participant13         Epithelial_cells
# ATGCGTAATTTA_COVID19_Participant13               Macrophage
# GTTAATCGGTAG_COVID19_Participant13         Epithelial_cells
# TCCTAACAAAGT_COVID19_Participant13                  T_cells
# AACAATGTGGCC_COVID19_Participant13         Epithelial_cells
# CTCGCCCTATAA_COVID19_Participant13         Epithelial_cells
# CTACAATAATAT_COVID19_Participant13                  T_cells
# CCAATATTGTCG_COVID19_Participant13         Epithelial_cells
# AATATTCCAGGA_COVID19_Participant13            Keratinocytes
# GGAATATAGTTC_COVID19_Participant13                       DC
# CTTCCGCTTTTG_COVID19_Participant13         Epithelial_cells
# CTGTTCCCATTA_COVID19_Participant13         Epithelial_cells
# CTATTATGATGG_COVID19_Participant13         Epithelial_cells
# AGATTATCATGT_COVID19_Participant13              Neutrophils
# TACCCTTTCAGT_COVID19_Participant13                  T_cells
# CTGTGATGAATG_COVID19_Participant13              Neutrophils
# GCCACCAACACC_COVID19_Participant13                       DC
# TTCATAATGGAC_COVID19_Participant13         Epithelial_cells
# CATAGCATGTCT_COVID19_Participant13         Epithelial_cells
# CGTTCTCGATAG_COVID19_Participant13         Epithelial_cells
# ATATTGCCCCGT_COVID19_Participant13         Epithelial_cells
# TTCATTGCGTTC_COVID19_Participant13              Neutrophils
# TAAGACTCGGGG_COVID19_Participant13                HSC_CD34+
# CTACAGAACAGA_COVID19_Participant13         Epithelial_cells
# TTGCACGGAAGC_COVID19_Participant13                  Neurons
# TTAGTTACTTCA_COVID19_Participant13                  NK_cell
# TTTAATAAGGCA_COVID19_Participant13         Epithelial_cells
# ATATACATGCCG_COVID19_Participant13                  T_cells
# AATCGATCACAC_COVID19_Participant13                  NK_cell
# AAGTGTGCCCTC_COVID19_Participant13                  T_cells
# AGCGATCAATGG_COVID19_Participant13                  T_cells
# CTTGACCTGTCT_COVID19_Participant13         Epithelial_cells
# TACAACCTTCAC_COVID19_Participant13                  T_cells
# TGGCAAAACTAT_COVID19_Participant13         Epithelial_cells
# TTGAATATCAAC_COVID19_Participant13               HSC_-G-CSF
# TTAAAGTGGTTA_COVID19_Participant13                  NK_cell
# CATTACGAATCC_COVID19_Participant13                       DC
# ATGGGAGATTAT_COVID19_Participant13         Epithelial_cells
# CCTCCGGACCTG_COVID19_Participant13         Epithelial_cells
# CTATAATAATGT_COVID19_Participant13               Macrophage
# CATCGTAAATTA_COVID19_Participant13         Epithelial_cells
# CTCCACAATCAT_COVID19_Participant13               Macrophage
# TGAATTGTCCAT_COVID19_Participant13         Epithelial_cells
# TTCTCCCTCGTT_COVID19_Participant13         Epithelial_cells
# GTCAAGACATGC_COVID19_Participant13                       DC
# TAGAAGGATCTT_COVID19_Participant13                  T_cells
# TCGTTCCACTCC_COVID19_Participant13              Neutrophils
# TGTTTGTCGTGA_COVID19_Participant13                HSC_CD34+
# AATTTCCCTATG_COVID19_Participant13                  NK_cell
# ATGTACACATAA_COVID19_Participant13         Epithelial_cells
# ACTCATATATCA_COVID19_Participant13         Epithelial_cells
# GCATATTAAACC_COVID19_Participant13         Epithelial_cells
# CCAAGTAGTCTA_COVID19_Participant13         Epithelial_cells
# CTGTCCGAAAAG_COVID19_Participant13         Epithelial_cells
# ATACAACCCCTT_COVID19_Participant13                  T_cells
# GCCGTCCACGTC_COVID19_Participant13         Epithelial_cells
# GCACCTTCCTGC_COVID19_Participant13         Epithelial_cells
# CCCAAAACAAAT_COVID19_Participant13               Macrophage
# AAGGAGAATGGA_COVID19_Participant13         Epithelial_cells
# GTCTCCGAAATA_COVID19_Participant13                  T_cells
# TGGATGAGCTCC_COVID19_Participant13         Epithelial_cells
# ACTACGTTCATA_COVID19_Participant13                      CMP
# TAGTTAGTATCT_COVID19_Participant13         Epithelial_cells
# GCTGTATCTTTC_COVID19_Participant13         Epithelial_cells
# GTTCCCCTCTCT_COVID19_Participant13                  T_cells
# TATTATCAACGA_COVID19_Participant13         Epithelial_cells
# CATTATAGGTTC_COVID19_Participant13         Epithelial_cells
# AATTGTATGTCA_COVID19_Participant13               HSC_-G-CSF
# TTCGATCTCATA_COVID19_Participant13         Epithelial_cells
# AAGGGACCGGTA_COVID19_Participant13                  T_cells
# AACAGGAGCTTG_COVID19_Participant13              Neutrophils
# TAGATCCGAACA_COVID19_Participant13         Epithelial_cells
# CTCAATGTAAAC_COVID19_Participant13         Epithelial_cells
# AGCATAGAGTTT_COVID19_Participant13            Keratinocytes
# CCAAAACTGACA_COVID19_Participant13               Macrophage
# TTCATCTGCCCT_COVID19_Participant13            Keratinocytes
# AAACCGTATATC_COVID19_Participant13               HSC_-G-CSF
# CGATATATTCAG_COVID19_Participant13                  NK_cell
# GATAAGAGAGTT_COVID19_Participant13                Astrocyte
# TCTACAGAGGCG_COVID19_Participant13              Fibroblasts
# AGACCACTTCTT_COVID19_Participant13         Epithelial_cells
# TCTTACTACGAG_COVID19_Participant13                  NK_cell
# TAGTGAATACTT_COVID19_Participant13         Epithelial_cells
# CGTCTCCTCTTA_COVID19_Participant13         Pre-B_cell_CD34-
# ACTATTGTTGAG_COVID19_Participant13         Epithelial_cells
# CGTTTTAAACTG_COVID19_Participant13               HSC_-G-CSF
# AGGTAAAGGGTT_COVID19_Participant13         Epithelial_cells
# ATCGAACAAGAG_COVID19_Participant13                  T_cells
# ACCTGGTAGTCT_COVID19_Participant13      Smooth_muscle_cells
# GTATAACTTCTG_COVID19_Participant13         Epithelial_cells
# ATAATTAAAGGG_COVID19_Participant13         Epithelial_cells
# CGAACTTGTGAT_COVID19_Participant13                      GMP
# TAGCTTCACTAA_COVID19_Participant13                   B_cell
# CACCTCTATAAT_COVID19_Participant13                HSC_CD34+
# ACTCTCACTACT_COVID19_Participant13         Epithelial_cells
# GAACAGTGCCTA_COVID19_Participant13         Pre-B_cell_CD34-
# GACACCATCTCG_COVID19_Participant13               HSC_-G-CSF
# TGTCATCATGCT_COVID19_Participant13         Epithelial_cells
# CAAGTAATGTTT_COVID19_Participant13              Gametocytes
# CATTCAATATAA_COVID19_Participant13               Macrophage
# GTGTCGGATTGG_COVID19_Participant13                       DC
# CACACATAGATC_COVID19_Participant13        Endothelial_cells
# GGTCATGCTTGC_COVID19_Participant13            Keratinocytes
# AGAATAACAGGG_COVID19_Participant13              Neutrophils
# ACAGGTTAGCAC_COVID19_Participant13         Epithelial_cells
# CTGCACATGGGG_COVID19_Participant13         Epithelial_cells
# TGGTACCTGAAG_COVID19_Participant13              Neutrophils
# AACATTATATAG_COVID19_Participant13                  T_cells
# AAGTCTTACGAT_COVID19_Participant13                  NK_cell
# TACACAACCGAA_COVID19_Participant13                      MSC
# GGCGTCACTTAC_COVID19_Participant13              Neutrophils
# GTATTCCCTGCA_COVID19_Participant13              Fibroblasts
# AGTTTTAACTGA_COVID19_Participant13                      CMP
# GTCGACGCCAAT_COVID19_Participant13                       DC
# CAAATTCACTAT_COVID19_Participant13                  T_cells
# TACAGGCCCTGA_COVID19_Participant13                 Monocyte
# TGGGGCTTGCTG_COVID19_Participant13                Myelocyte
# GGCGCAGACCGA_COVID19_Participant13            Keratinocytes
# CTAGAGCACACT_COVID19_Participant13            Keratinocytes
# TTTTCGTGGGCG_COVID19_Participant13               HSC_-G-CSF
# CCTGTTCATTGC_COVID19_Participant13         Epithelial_cells
# TACGTAAAACCA_COVID19_Participant13         Epithelial_cells
# ACAAGACTAGCA_COVID19_Participant13                 Monocyte
# GCCCTCCCTATA_COVID19_Participant13         Epithelial_cells
# CGTCACAATGAG_COVID19_Participant13                  Neurons
# TACTAATGGGTT_COVID19_Participant13         Epithelial_cells
# CTGAAAATGGGG_COVID19_Participant13     Embryonic_stem_cells
# TACTAGTTCTTG_COVID19_Participant13              Neutrophils
# GAGTAGGGTTAG_COVID19_Participant13            Keratinocytes
# GATCGCTGTCCT_COVID19_Participant13         Epithelial_cells
# CACTAACAGTTT_COVID19_Participant13                 Monocyte
# TTTTGTCTTAGC_COVID19_Participant13         Epithelial_cells
# CATCTAAGGCCT_COVID19_Participant13                  T_cells
# AGATCTGATATC_COVID19_Participant13        Tissue_stem_cells
# GGAAGACCGATA_COVID19_Participant13                  T_cells
# CTTTGGTTTCTT_COVID19_Participant13                  NK_cell
# CTGTTCACCGCT_COVID19_Participant13               Macrophage
# GGCCCATGTAAA_COVID19_Participant13         Epithelial_cells
# GTATATTTGAGA_COVID19_Participant13         Epithelial_cells
# AGTGCTCTTGCG_COVID19_Participant13                  Neurons
# CGAGTCTTCTGG_COVID19_Participant13         Epithelial_cells
# AAAGCAGTACAT_COVID19_Participant13                   B_cell
# AGTATAAGTCTC_COVID19_Participant13                  NK_cell
# TTTTTATTATTT_COVID19_Participant13         Epithelial_cells
# TAATGCCTTAAG_COVID19_Participant13                 Monocyte
# ACACCCGACGGA_COVID19_Participant13                Astrocyte
# TCAATTTGCAAC_COVID19_Participant13                  NK_cell
# AAGACAATCTGT_COVID19_Participant13         Epithelial_cells
# AGCCTAAAAACA_COVID19_Participant13         Epithelial_cells
# GGTGAAATTCAT_COVID19_Participant13            Keratinocytes
# GCGATACGCATT_COVID19_Participant13                  NK_cell
# CAATCATCATCC_COVID19_Participant13         Epithelial_cells
# GTCATCGAAGCT_COVID19_Participant13         Epithelial_cells
# CTCCTTGATGAC_COVID19_Participant13               HSC_-G-CSF
# AGTTAAGGCCCG_COVID19_Participant13         Epithelial_cells
# TATCAGAATGCT_COVID19_Participant13               Macrophage
# TGGTGACCCCTA_COVID19_Participant13                 Monocyte
# ATAATTGAACCA_COVID19_Participant13         Epithelial_cells
# AGCGTTATGCAC_COVID19_Participant13         Epithelial_cells
# CCTTGCACGCAT_COVID19_Participant13         Epithelial_cells
# GCGCTTGTAGAA_COVID19_Participant13         Epithelial_cells
# TCCAAAAGGATC_COVID19_Participant13               Macrophage
# TCTACTTTGCTA_COVID19_Participant13              Gametocytes
# ACTTAACCTCTT_COVID19_Participant13         Epithelial_cells
# AATTAGCCTATC_COVID19_Participant13                      CMP
# TTAGAACCATCA_COVID19_Participant13         Epithelial_cells
# AAGCAATAAGCC_COVID19_Participant13               Macrophage
# ACCCCGCAATCC_COVID19_Participant13                 Monocyte
# TAACTAGGTTTT_COVID19_Participant13         Epithelial_cells
# GTGCGTCATGTC_COVID19_Participant13                 Monocyte
# TACCGGGGCCTA_COVID19_Participant13         Epithelial_cells
# GGAGCTAAAGTT_COVID19_Participant13         Epithelial_cells
# TCCGTTTTTGGG_COVID19_Participant13                Platelets
# TAATGCAATAAT_COVID19_Participant13                  NK_cell
# GTGGTGGAGTTC_COVID19_Participant13                  T_cells
# CTCGTCGGTTTT_COVID19_Participant13         Epithelial_cells
# CAATCAATCACA_COVID19_Participant13              Osteoblasts
# CACGGCGCTGGG_COVID19_Participant13         Epithelial_cells
# AGAAGACCGCTT_COVID19_Participant13         Epithelial_cells
# TTCCAATCACGA_COVID19_Participant13                  NK_cell
# GAGTATTTCCTT_COVID19_Participant13         Epithelial_cells
# AGTAGTTTGGCT_COVID19_Participant13                  T_cells
# TGACAATCCAGG_COVID19_Participant13            Keratinocytes
# TCTTTCAACACA_COVID19_Participant13         Epithelial_cells
# AGCCCAGAGATG_COVID19_Participant13              Gametocytes
# GAAGGAATGTCA_COVID19_Participant13                  T_cells
# CTAACGTGCTTG_COVID19_Participant13                  T_cells
# TTTGTCCATCCG_COVID19_Participant13         Epithelial_cells
# TGAATCAATGCT_COVID19_Participant13                  T_cells
# TAGTAGTATTCT_COVID19_Participant13         Epithelial_cells
# TTGGTAGTAATT_COVID19_Participant13         Epithelial_cells
# CTTCTTCTGGTG_COVID19_Participant13                 Monocyte
# TCCCGGCATTTT_COVID19_Participant13         Epithelial_cells
# CGTAGATCCCAA_COVID19_Participant13                 Monocyte
# TAGACACGGTAA_COVID19_Participant13         Epithelial_cells
# ACCGCGCAATCT_COVID19_Participant13         Epithelial_cells
# TGGCAGTAAATT_COVID19_Participant13                  T_cells
# GGCTAATACTGA_COVID19_Participant13         Epithelial_cells
# TGAGCCTGTTTC_COVID19_Participant13                  T_cells
# GACACAGAATAG_COVID19_Participant13              Neutrophils
# AATGTCTTGTTA_COVID19_Participant13                  T_cells
# CACAATATTTAT_COVID19_Participant13         Epithelial_cells
# CTCGCGGACGTC_COVID19_Participant13         Epithelial_cells
# CTCGGGGATTTA_COVID19_Participant13                  T_cells
# AGATGATCGTAT_COVID19_Participant13         Epithelial_cells
# CACAATGTTGAC_COVID19_Participant13              Neutrophils
# CGAAGCAATTAT_COVID19_Participant13               Macrophage
# GACCGCCCCTTA_COVID19_Participant13               Macrophage
# TTCGTACCCTTA_COVID19_Participant13               Macrophage
# CATCGCTATTCG_COVID19_Participant13                  Neurons
# GTGGGGTGGCCC_COVID19_Participant13                  T_cells
# AAGTCTTGAGAG_COVID19_Participant13              Gametocytes
# ACAACTGCGAAG_COVID19_Participant13         Epithelial_cells
# GACACACAAAGC_COVID19_Participant13         Epithelial_cells
# AAAGGATGTTCA_COVID19_Participant13                  T_cells
# GAGATAACTCTC_COVID19_Participant13         Epithelial_cells
# ATGCGGGCTAAT_COVID19_Participant13         Epithelial_cells
# TACCCTAAGAGA_COVID19_Participant13                   B_cell
# CATACGTGATAT_COVID19_Participant13                  T_cells
# AATCATCGTGTA_COVID19_Participant13         Epithelial_cells
# CGCAAATAACCT_COVID19_Participant13         Epithelial_cells
# TGGTGACACCAC_COVID19_Participant13            Keratinocytes
# CAGTAGATTGCA_COVID19_Participant13         Epithelial_cells
# GCAGGTTATGAT_COVID19_Participant13         Epithelial_cells
# TTCACAAAGTCA_COVID19_Participant13                  T_cells
# TATCGAGGGTAG_COVID19_Participant13                  NK_cell
# GATCGGTTCAGT_COVID19_Participant13                  NK_cell
# AAGTGTTCTAAA_COVID19_Participant13         Epithelial_cells
# GCAACCGGCCTG_COVID19_Participant13         Pre-B_cell_CD34-
# TCCAATAAGTTT_COVID19_Participant13                  T_cells
# GAGTACGAGATA_COVID19_Participant13         Epithelial_cells
# GTGTAGTTAAAG_COVID19_Participant13                  NK_cell
# TGAGAATTACGG_COVID19_Participant13                  Neurons
# ACCCTCACACAA_COVID19_Participant13         Epithelial_cells
# GAGATGTGCTAC_COVID19_Participant13               HSC_-G-CSF
# GTTTTTAGACTT_COVID19_Participant13                  T_cells
# CTAATCGGGCGT_COVID19_Participant13         Epithelial_cells
# AAAGTAGTCGCA_COVID19_Participant13                  T_cells
# GCCGTCCATCTC_COVID19_Participant13            Keratinocytes
# GGCAAATGTGGA_COVID19_Participant13         Epithelial_cells
# GTCTAGTGGTTT_COVID19_Participant13         Epithelial_cells
# ATTAAATCTCAC_COVID19_Participant13            Keratinocytes
# AGGACAAGGCAG_COVID19_Participant13         Epithelial_cells
# TGACGATCATGC_COVID19_Participant13            Keratinocytes
# TTCACCACCTGA_COVID19_Participant13                  Neurons
# TCTTCCGGGCAC_COVID19_Participant13              Neutrophils
# GTACAAAGAGTC_COVID19_Participant13         Pre-B_cell_CD34-
# CGAACTCTTGAA_COVID19_Participant13                  NK_cell
# GTTATAGGTCAG_COVID19_Participant13              Neutrophils
# TAGGTCGTCACA_COVID19_Participant13         Epithelial_cells
# AACGCAGCATGT_COVID19_Participant13         Epithelial_cells
# TCTGTGTTCGTA_COVID19_Participant13              Neutrophils
# TACTCGTAGAGA_COVID19_Participant13         Epithelial_cells
# CAAGTAAATCTT_COVID19_Participant13         Pre-B_cell_CD34-
# AATTCAGAAACG_COVID19_Participant13               HSC_-G-CSF
# GCCGTTTAGGTG_COVID19_Participant13                      MEP
# TCTCGTCGAATG_COVID19_Participant13                Myelocyte
# AGTGGTGTCACA_COVID19_Participant13                  NK_cell
# GTCACCCGTCCG_COVID19_Participant13         Epithelial_cells
# GCATTATCTCAG_COVID19_Participant13            Keratinocytes
# GAATTGCGAGGC_COVID19_Participant13            Keratinocytes
# GATTTCCTTCCT_COVID19_Participant13                       DC
# CATTAGACAGTT_COVID19_Participant13                  NK_cell
# CCTAGATTACTT_COVID19_Participant13      Smooth_muscle_cells
# GGGTAGCTCACA_COVID19_Participant13         Epithelial_cells
# TACCAACTCCGC_COVID19_Participant13         Epithelial_cells
# GTAACTCCGTAA_COVID19_Participant13         Epithelial_cells
# TGAAACTTGTAA_COVID19_Participant13             Erythroblast
# ACGTAATTGTCC_COVID19_Participant13         Epithelial_cells
# CAACTTGGCGAT_COVID19_Participant13         Epithelial_cells
# TAATATAAGCGT_COVID19_Participant13         Epithelial_cells
# TTGCCTGGTGTA_COVID19_Participant13                  T_cells
# GGTACTCTCCTT_COVID19_Participant13              Neutrophils
# TACTTCATCCTT_COVID19_Participant13            Keratinocytes
# ATAACGCGAATT_COVID19_Participant13                  NK_cell
# AGTACTACACGT_COVID19_Participant13                  T_cells
# TTACCATATCGT_COVID19_Participant13                  T_cells
# TATATCACTTCT_COVID19_Participant13                  T_cells
# TGCTACCGCTAA_COVID19_Participant13         Epithelial_cells
# CCCTGACACAAG_COVID19_Participant13                       BM
# TTGAAGAACAGC_COVID19_Participant13                  NK_cell
# GGTTAGAACCCC_COVID19_Participant13         Epithelial_cells
# TGTAAGTAATCG_COVID19_Participant13                  Neurons
# ATTTACTCCCGC_COVID19_Participant13            Keratinocytes
# TACATGGATACG_COVID19_Participant13         Epithelial_cells
# CAAGACCGCTGC_COVID19_Participant13                  T_cells
# CGGTACCCTACA_COVID19_Participant13         Epithelial_cells
# CCGTACCCCCAC_COVID19_Participant13                  T_cells
# ACGCTGTAAATG_COVID19_Participant13         Epithelial_cells
# ACCTTCCGGTGA_COVID19_Participant13                       DC
# TATCTGGATTTT_COVID19_Participant13         Epithelial_cells
# AGCATCTTATTG_COVID19_Participant13              Neutrophils
# TAGCTGACCTGG_COVID19_Participant13         Epithelial_cells
# GACGTTTAGCCC_COVID19_Participant13            Keratinocytes
# GTCAAGCCCATC_COVID19_Participant13            Keratinocytes
# TTGCGGTGACCA_COVID19_Participant31         Epithelial_cells
# AGGCTCGAACTG_COVID19_Participant31         Epithelial_cells
# TATCCGTATGTT_COVID19_Participant31                  NK_cell
# CAGACAGCGGCT_COVID19_Participant31         Epithelial_cells
# CAAAGAGAACTA_COVID19_Participant31         Epithelial_cells
# AACCTGAAGTCA_COVID19_Participant31            Keratinocytes
# GTCCTTGTTAGA_COVID19_Participant31         Epithelial_cells
# TTCCTTGATGAG_COVID19_Participant31         Epithelial_cells
# CAGGCCTCTTTT_COVID19_Participant31         Epithelial_cells
# GCGGAAGTGATG_COVID19_Participant31         Epithelial_cells
# ACAGTCCGGGGT_COVID19_Participant31         Epithelial_cells
# CCTTAGAAACCT_COVID19_Participant31               Macrophage
# AGCAAGTGACTG_COVID19_Participant31                  Neurons
# TTGCAGACGGGA_COVID19_Participant31         Epithelial_cells
# GGCTTTGAGTTT_COVID19_Participant31            Keratinocytes
# AATCGAGAAGCC_COVID19_Participant31         Epithelial_cells
# CCGTAACTGGTC_COVID19_Participant31         Epithelial_cells
# CTCTGAACTCGG_COVID19_Participant31         Epithelial_cells
# TTCTGTATTTGG_COVID19_Participant31         Epithelial_cells
# GAAATGTCACAC_COVID19_Participant31                  T_cells
# CTCGCTAATTAG_COVID19_Participant31         Epithelial_cells
# TCATAGCCAGAT_COVID19_Participant31         Epithelial_cells
# TCCTTTGGAAAA_COVID19_Participant31         Epithelial_cells
# ATTCTCGCAGCT_COVID19_Participant31                 Monocyte
# ACCGTTATTCTT_COVID19_Participant31         Epithelial_cells
# GTTTTACGATCA_COVID19_Participant31         Epithelial_cells
# GTCCCTGCTACC_COVID19_Participant31                  Neurons
# TTCATGGTGAAG_COVID19_Participant31         Epithelial_cells
# CTAACGGGTAGC_COVID19_Participant31         Epithelial_cells
# CGGATGAGTGGG_COVID19_Participant31         Epithelial_cells
# CCCGCCCATGTG_COVID19_Participant31         Epithelial_cells
# TGTCACCCTATA_COVID19_Participant31                  Neurons
# ATAACGAAAAGA_COVID19_Participant31            Keratinocytes
# ACGTCCGCACGA_COVID19_Participant31         Epithelial_cells
# GGAGAGTCTCTC_COVID19_Participant31            Keratinocytes
# TTTGGCTGTCGT_COVID19_Participant31         Epithelial_cells
# CCAGCCTATTTA_COVID19_Participant31         Epithelial_cells
# ATGAGAATCTCG_COVID19_Participant31         Epithelial_cells
# CGAACTATCTTC_COVID19_Participant31                  NK_cell
# CATAAACGGCGC_COVID19_Participant31         Epithelial_cells
# CCCTGAAATATC_COVID19_Participant31         Epithelial_cells
# GATGGAATTTTG_COVID19_Participant31         Epithelial_cells
# ATAACTTTAGCC_COVID19_Participant31                  T_cells
# CTCAGCATACGG_COVID19_Participant31                  Neurons
# CTCCGGGCGCTC_COVID19_Participant31         Epithelial_cells
# CCTCTGACGGTA_COVID19_Participant31         Epithelial_cells
# CTTCCTGGACTT_COVID19_Participant31                  T_cells
# GAACGTACCCCG_COVID19_Participant31         Epithelial_cells
# ACAGACGCACAT_COVID19_Participant31            Keratinocytes
# GGGCTGATTCAA_COVID19_Participant31         Epithelial_cells
# CGAAAGCCCGGA_COVID19_Participant31                  Neurons
# AGACTCGCCTTC_COVID19_Participant31         Epithelial_cells
# ATTGCGGACGTC_COVID19_Participant31                  T_cells
# TTCGGGGCTCAA_COVID19_Participant31         Epithelial_cells
# ATACCCAGCTCT_COVID19_Participant31             Chondrocytes
# CAGGAAAACTTA_COVID19_Participant31                  T_cells
# TGAGGCGTGAGT_COVID19_Participant31         Epithelial_cells
# CCAAGGATGCCC_COVID19_Participant31                 Monocyte
# ATTATTTAGTAG_COVID19_Participant31         Epithelial_cells
# ACGGCATCCCGG_COVID19_Participant31         Epithelial_cells
# AGCCGTAAAGAA_COVID19_Participant31         Epithelial_cells
# CCTGTCAAGGAT_COVID19_Participant31            Keratinocytes
# GGCGTTAACGGT_COVID19_Participant31         Epithelial_cells
# GTGAACGCCATC_COVID19_Participant31         Epithelial_cells
# TGCCGGGTTTAT_COVID19_Participant31                  NK_cell
# ATGGCACCTCTG_COVID19_Participant31            Keratinocytes
# GACAAGAGCATT_COVID19_Participant31         Epithelial_cells
# TCTTTGTACCGC_COVID19_Participant31         Epithelial_cells
# GAAAGGTCCAGA_COVID19_Participant31                  Neurons
# ...
# AGCGCTGAGCGG_COVID19_Participant18           Keratinocytes
# TACACCCGATAC_COVID19_Participant18        Epithelial_cells
# TTCTATAGATGC_COVID19_Participant18        Epithelial_cells
# TGAAGGTTTAAT_COVID19_Participant18        Epithelial_cells
# CATCGCCTCGCG_COVID19_Participant18           Keratinocytes
# ACACGATTCTTA_COVID19_Participant18           Keratinocytes
# ATATGGTCTAGA_COVID19_Participant18                     MSC
# AACTCCGCCATC_COVID19_Participant18           Keratinocytes
# CGTAACCTCTGA_COVID19_Participant18           Keratinocytes
# TTAAATGCCGTA_COVID19_Participant18        Epithelial_cells
# CAACAGAAATTG_COVID19_Participant18        Epithelial_cells
# ACAAGAGAGTAT_COVID19_Participant18           Keratinocytes
# AGCAAGTGGTAA_COVID19_Participant18                      DC
# CATCAAAGGCTC_COVID19_Participant18        Epithelial_cells
# TGGACTGTCAAA_COVID19_Participant18        Epithelial_cells
# AAGAGAGATGAT_COVID19_Participant18        Epithelial_cells
# ACGTCATTTAAG_COVID19_Participant18        Epithelial_cells
# GTGTCACAGATA_COVID19_Participant18           Keratinocytes
# CTTGTATGCTGG_COVID19_Participant18           Keratinocytes
# GAGTATCAGGTT_COVID19_Participant18             Neutrophils
# TCCTGACGACAA_COVID19_Participant18        Epithelial_cells
# GTACAGTGTGGC_COVID19_Participant18           Keratinocytes
# ATTCTGCCATCT_COVID19_Participant18        Epithelial_cells
# GTCAGGGTCACG_COVID19_Participant18        Epithelial_cells
# CCAATCAGGTAG_COVID19_Participant18        Epithelial_cells
# CACGATGTTCCA_COVID19_Participant18        Epithelial_cells
# ATCACTTCGACG_COVID19_Participant18        Epithelial_cells
# TTGGTAGTTAGA_COVID19_Participant18           Keratinocytes
# GTTTATTAGTGG_COVID19_Participant18        Epithelial_cells
# CTTTCGCCCAGG_COVID19_Participant18        Epithelial_cells
# ATAGGTACGGGA_COVID19_Participant18        Epithelial_cells
# AGTCAGGATCTA_COVID19_Participant18        Epithelial_cells
# GCTTTGGCAGGT_COVID19_Participant18        Epithelial_cells
# TAGTGGCTGATT_COVID19_Participant18        Epithelial_cells
# ACGTACGAGGCT_COVID19_Participant18        Epithelial_cells
# TCATCTCTGGCC_COVID19_Participant18           Keratinocytes
# ACAGCAATTTGG_COVID19_Participant18        Epithelial_cells
# CACCACCACCTT_COVID19_Participant18           Keratinocytes
# TTCCGACTTGTA_COVID19_Participant18        Epithelial_cells
# ATCATAAGCCTT_COVID19_Participant18           Keratinocytes
# TAGCCCCATTTC_COVID19_Participant18        Epithelial_cells
# CCCTTATATTAT_COVID19_Participant18        Epithelial_cells
# GGAATGGCGTTT_COVID19_Participant18        Epithelial_cells
# AGCCGACCCTAA_COVID19_Participant18        Epithelial_cells
# AGACCTAAAACC_COVID19_Participant18           Keratinocytes
# CGGCCTCCGCCC_COVID19_Participant18        Epithelial_cells
# CTGTCATGCACT_COVID19_Participant18        Epithelial_cells
# AGCTATTCATTG_COVID19_Participant18        Epithelial_cells
# ACCTCAGGAATA_COVID19_Participant18        Epithelial_cells
# CAGGCGTTCTTC_COVID19_Participant18           Keratinocytes
# ACTCCCATTCAG_COVID19_Participant18                 NK_cell
# TCAAGCTATCGT_COVID19_Participant18                 NK_cell
# CTCGCCCTGGTT_COVID19_Participant18        Epithelial_cells
# TGGCTTACCGCC_COVID19_Participant18        Epithelial_cells
# GTATATCACTCG_COVID19_Participant18           Keratinocytes
# GACCCAGTCCTG_COVID19_Participant18               Astrocyte
# GTACACAGAGAA_COVID19_Participant18       Endothelial_cells
# GGGCCTTTTCCC_COVID19_Participant18        Epithelial_cells
# CGTCTACGTGAG_COVID19_Participant18        Epithelial_cells
# TAAAATTTAGGA_COVID19_Participant18           Keratinocytes
# TGCGCGTTCCAG_COVID19_Participant18        Epithelial_cells
# CCGCACGAGACC_COVID19_Participant18           Keratinocytes
# AGAACCTGAATT_COVID19_Participant18        Epithelial_cells
# CCTGCCCCATGA_COVID19_Participant18        Epithelial_cells
# AATTGCTACGGC_COVID19_Participant18        Epithelial_cells
# ATGCCACTTTCA_COVID19_Participant18        Epithelial_cells
# AAAGTGATAGTT_COVID19_Participant18               Platelets
# TTTTCTGCTTCC_COVID19_Participant18        Epithelial_cells
# GTGGACATGACC_COVID19_Participant18        Epithelial_cells
# CCGTTACATTAA_COVID19_Participant18        Epithelial_cells
# GACATATTAGTG_COVID19_Participant18        Epithelial_cells
# TGTGGATACACA_COVID19_Participant18               Platelets
# CCCAGGCTGTCC_COVID19_Participant18        Epithelial_cells
# TCAACTCCCGGT_COVID19_Participant18        Epithelial_cells
# TCACTCGTGGTT_COVID19_Participant18              HSC_-G-CSF
# ATACCATTAGTA_COVID19_Participant18        Epithelial_cells
# GCTGTGGGAAAT_COVID19_Participant18           Keratinocytes
# AACTTGGACTAG_COVID19_Participant18        Epithelial_cells
# GGTTCCGCGATT_COVID19_Participant18           Keratinocytes
# CCGTAATGACGG_COVID19_Participant18        Epithelial_cells
# ACCGCACGAGGT_COVID19_Participant18        Epithelial_cells
# AGATACGACCTA_COVID19_Participant18           Keratinocytes
# CTGTCGCTGGCA_COVID19_Participant18        Epithelial_cells
# CGTGCGGTTTTC_COVID19_Participant18                      BM
# TATAGAGGTCCC_COVID19_Participant18        Epithelial_cells
# GAACTGGCAGAA_COVID19_Participant18                 Neurons
# TGCGGTATCAAT_COVID19_Participant18        Epithelial_cells
# ACCACCCTTTAA_COVID19_Participant18        Epithelial_cells
# TTCGGTTCCAGC_COVID19_Participant18        Epithelial_cells
# AAATTACTCAGC_COVID19_Participant18        Epithelial_cells
# CTTGCTTACTGG_COVID19_Participant18        Epithelial_cells
# AAGCCGTTCTGG_COVID19_Participant18             Gametocytes
# TCTAGGTGTCTA_COVID19_Participant18           Keratinocytes
# TAAAACTATATT_COVID19_Participant18        Epithelial_cells
# ACACGGTAAGAC_COVID19_Participant18        Epithelial_cells
# CACAAACCCACG_COVID19_Participant18           Keratinocytes
# TTTCAAACTTCT_COVID19_Participant18        Epithelial_cells
# CCAACTTTCAAT_COVID19_Participant30        Epithelial_cells
# GATACGGGCCAG_COVID19_Participant30                      BM
# GTGCAAAAGAAC_COVID19_Participant30        Epithelial_cells
# CTATTGCCACTG_COVID19_Participant30              HSC_-G-CSF
# GATTTTGAAACG_COVID19_Participant30        Epithelial_cells
# GTTACAACTCAG_COVID19_Participant30               Myelocyte
# ATAACGACGACT_COVID19_Participant30           Keratinocytes
# TCTTCTCAACAG_COVID19_Participant30           Keratinocytes
# GAGCCTACACAT_COVID19_Participant30           Keratinocytes
# TGAGTTAGGTAC_COVID19_Participant30        Epithelial_cells
# TTGACCACAACC_COVID19_Participant30        Epithelial_cells
# CGAGCAGAGGTT_COVID19_Participant30           Keratinocytes
# CGAGCTTCAGTG_COVID19_Participant30        Epithelial_cells
# TAGCTAGCCTGC_COVID19_Participant30        Epithelial_cells
# TTATACCTCTTA_COVID19_Participant30             Neutrophils
# AGACGAAACCAG_COVID19_Participant30        Epithelial_cells
# GTTCAACGTGCG_COVID19_Participant30           Keratinocytes
# GCGGCGCACCAG_COVID19_Participant30        Epithelial_cells
# ACAAAGCACGGC_COVID19_Participant30           Keratinocytes
# GGATTGCCCACG_COVID19_Participant30           Keratinocytes
# GCTAGGAGGACA_COVID19_Participant30                      DC
# ATCCTCCGCCTC_COVID19_Participant30           Keratinocytes
# TGGCGAATCCGA_COVID19_Participant30           Keratinocytes
# AGCAGGAAGCTC_COVID19_Participant30             Neutrophils
# GGTCAGTATATT_COVID19_Participant30           Keratinocytes
# TCATTCACTATG_COVID19_Participant30           Keratinocytes
# ACACACGAGTTG_COVID19_Participant30        Epithelial_cells
# CCGTCTGCATCG_COVID19_Participant30        Epithelial_cells
# ACGTAAAATTCA_COVID19_Participant30           Keratinocytes
# ACCCCTATTTTG_COVID19_Participant30             Neutrophils
# ATACTATGTTGC_COVID19_Participant30        Epithelial_cells
# TACACGAGGCCC_COVID19_Participant30              Macrophage
# GTAGTATTAACA_COVID19_Participant30           Keratinocytes
# GATCTAGTAATT_COVID19_Participant30           Keratinocytes
# CATCCGGTCCTG_COVID19_Participant30           Keratinocytes
# TGCTTCAAGGAT_COVID19_Participant30        Epithelial_cells
# AATACCACCAGG_COVID19_Participant30        Epithelial_cells
# GACAGTTGGTCC_COVID19_Participant30        Epithelial_cells
# TAACTACAGCTT_COVID19_Participant30              Macrophage
# GTTAGTTGGCGG_COVID19_Participant30           Keratinocytes
# TACCCATGCTTT_COVID19_Participant30        Epithelial_cells
# GTAATGCCAAGG_COVID19_Participant30               Platelets
# TGCACACTCCGT_COVID19_Participant30             Neutrophils
# CGTTAGTCTTAG_COVID19_Participant30        Epithelial_cells
# GCAAGTCACCAT_COVID19_Participant30           Keratinocytes
# GAGTTTGTTTTT_COVID19_Participant30           Keratinocytes
# CGCTTCGTGTGT_COVID19_Participant30           Keratinocytes
# CGAACTGTTAGA_COVID19_Participant30             Neutrophils
# TTACGATGCTGT_COVID19_Participant30             Osteoblasts
# TGGGATTACAGG_COVID19_Participant30    Neuroepithelial_cell
# GCTACCCTGAGG_COVID19_Participant30             Neutrophils
# AAATCGTTACTA_COVID19_Participant30        Epithelial_cells
# GTCGAAAGACTT_COVID19_Participant30        Epithelial_cells
# TTTCAGGTGGTC_COVID19_Participant30           Keratinocytes
# CGCTGGTTAAGT_COVID19_Participant30               Platelets
# AGAAGTATCTGG_COVID19_Participant30           Keratinocytes
# TAAAGCTCACTT_COVID19_Participant30           Keratinocytes
# ATCCCCTTGCAC_COVID19_Participant30           Keratinocytes
# CAGCTGGCAAAT_COVID19_Participant30           Keratinocytes
# CACATTTTAAAT_COVID19_Participant30        Epithelial_cells
# CGCATGGTGGCC_COVID19_Participant30           Keratinocytes
# TCGCGAGGGAGA_COVID19_Participant30           Keratinocytes
# AGGGGAGCGACT_COVID19_Participant30        Epithelial_cells
# GACCCGGGTAGT_COVID19_Participant30           Keratinocytes
# ATTAACGACGTG_COVID19_Participant30           Keratinocytes
# AAACGAACATAC_COVID19_Participant30        Epithelial_cells
# CGAGACTGTCAC_COVID19_Participant30           Keratinocytes
# CAACCCAAGCTG_COVID19_Participant30        Epithelial_cells
# TTTGAATTAGAA_COVID19_Participant30           Keratinocytes
# GGTTGGCCTCAG_COVID19_Participant30             Neutrophils
# CTATCAAAGAGT_COVID19_Participant30             Neutrophils
# AAAAGACATATA_COVID19_Participant30           Keratinocytes
# ATATGCGCCGGG_COVID19_Participant30        Epithelial_cells
# CATACTCCTGGT_COVID19_Participant30             Neutrophils
# AACGCTCTGAGT_COVID19_Participant30        Epithelial_cells
# CTGGAAGAGCAG_COVID19_Participant30        Epithelial_cells
# AGAATAAGTGAG_COVID19_Participant30        Epithelial_cells
# CATCGATAACAA_COVID19_Participant30        Epithelial_cells
# TGCCGACGTCTG_COVID19_Participant30           Keratinocytes
# CGCACATACTTT_COVID19_Participant30        Epithelial_cells
# CATAGGCTGAGC_COVID19_Participant30           Keratinocytes
# CGTCCTTGAAAG_COVID19_Participant30        Epithelial_cells
# AGAAGACGTTAC_COVID19_Participant30           Keratinocytes
# ATTCATCCTCGT_COVID19_Participant30        Epithelial_cells
# TGTTTATTCGAG_COVID19_Participant30        Epithelial_cells
# CTCAGGGCGAAT_COVID19_Participant30           Keratinocytes
# CAGGTTAGGTTC_COVID19_Participant30           Keratinocytes
# ATCTCTAAGCTT_COVID19_Participant30        Epithelial_cells
# TAAGGATTACGT_COVID19_Participant30        Epithelial_cells
# GAGATCACTTCC_COVID19_Participant30             Neutrophils
# GACCTGTACATC_COVID19_Participant30           Keratinocytes
# GGACGACATTCA_COVID19_Participant30           Keratinocytes
# TGCACATTCGGC_COVID19_Participant30           Keratinocytes
# ACGCATCTAGGG_COVID19_Participant30        Epithelial_cells
# CCTCGAACCCCC_COVID19_Participant30        Epithelial_cells
# TTATATTAGCAT_COVID19_Participant30        Epithelial_cells
# TTGGTTGCCAAC_COVID19_Participant30        Epithelial_cells
# TTCCTATCCATC_COVID19_Participant30             Osteoblasts
# CGACTTTATCTG_COVID19_Participant30        Epithelial_cells
# AGAATCCGACCT_COVID19_Participant30           Keratinocytes
# GACATATTTCTG_COVID19_Participant30        Epithelial_cells
# ACACGTCCAGTC_COVID19_Participant30        Epithelial_cells
# AGAAGGTCAAAG_COVID19_Participant30        Epithelial_cells
# TGATCAAGCTGC_COVID19_Participant30        Epithelial_cells
# CCATTACCCCTC_COVID19_Participant30           Keratinocytes
# GGCGCTCAGAAT_COVID19_Participant30        Epithelial_cells
# GCCAAACAAAAT_COVID19_Participant30        Epithelial_cells
# CACGCCGTAATT_COVID19_Participant30        Epithelial_cells
# CGCTACTAGACT_COVID19_Participant30        Epithelial_cells
# CCTGATTTGTAC_COVID19_Participant30             Hepatocytes
# TTTCTAACGAGT_COVID19_Participant30           Keratinocytes
# GCAGGGAACTCC_COVID19_Participant30        Epithelial_cells
# CAGCACCGAGCC_COVID19_Participant30        Epithelial_cells
# GCCCCTTGTGAT_COVID19_Participant30        Epithelial_cells
# GTGTTGTGTGTC_COVID19_Participant30                  B_cell
# TAACACTCACTT_COVID19_Participant30               Myelocyte
# Name: singler_annotation, dtype: string
# 라벨별 그룹 개수 {1: 7, 0: 3}
# 🔍 Split #1
#   → train_p_index 환자 수: 40
#   → test_p_index 환자 수: 10
#   → train 환자 ID: ['COVID19_Participant10', 'COVID19_Participant12', 'COVID19_Participant13', 'COVID19_Participant14', 'COVID19_Participant15', 'COVID19_Participant17', 'COVID19_Participant19', 'COVID19_Participant2', 'COVID19_Participant20', 'COVID19_Participant21', 'COVID19_Participant22', 'COVID19_Participant23', 'COVID19_Participant26', 'COVID19_Participant27', 'COVID19_Participant29', 'COVID19_Participant3', 'COVID19_Participant31', 'COVID19_Participant32', 'COVID19_Participant35', 'COVID19_Participant36', 'COVID19_Participant37', 'COVID19_Participant38', 'COVID19_Participant4', 'COVID19_Participant40', 'COVID19_Participant5', 'COVID19_Participant6', 'COVID19_Participant7', 'COVID19_Participant9', 'Control_Participant1', 'Control_Participant10', 'Control_Participant11', 'Control_Participant12', 'Control_Participant13', 'Control_Participant15', 'Control_Participant2', 'Control_Participant3', 'Control_Participant4', 'Control_Participant5', 'Control_Participant6', 'Control_Participant8']
#   → test  환자 ID: ['COVID19_Participant11', 'COVID19_Participant18', 'COVID19_Participant25', 'COVID19_Participant28', 'COVID19_Participant30', 'COVID19_Participant39', 'COVID19_Participant8', 'Control_Participant14', 'Control_Participant7', 'Control_Participant9']
#   → train 환자 ID 및 라벨:
#     ID: COVID19_Participant10, Label: 1
#     ID: COVID19_Participant12, Label: 1
#     ID: COVID19_Participant13, Label: 1
#     ID: COVID19_Participant14, Label: 1
#     ID: COVID19_Participant15, Label: 1
#     ID: COVID19_Participant17, Label: 1
#     ID: COVID19_Participant19, Label: 1
#     ID: COVID19_Participant2, Label: 1
#     ID: COVID19_Participant20, Label: 1
#     ID: COVID19_Participant21, Label: 1
#     ID: COVID19_Participant22, Label: 1
#     ID: COVID19_Participant23, Label: 1
#     ID: COVID19_Participant26, Label: 1
#     ID: COVID19_Participant27, Label: 1
#     ID: COVID19_Participant29, Label: 1
#     ID: COVID19_Participant3, Label: 1
#     ID: COVID19_Participant31, Label: 1
#     ID: COVID19_Participant32, Label: 1
#     ID: COVID19_Participant35, Label: 1
#     ID: COVID19_Participant36, Label: 1
#     ID: COVID19_Participant37, Label: 1
#     ID: COVID19_Participant38, Label: 1
#     ID: COVID19_Participant4, Label: 1
#     ID: COVID19_Participant40, Label: 1
#     ID: COVID19_Participant5, Label: 1
#     ID: COVID19_Participant6, Label: 1
#     ID: COVID19_Participant7, Label: 1
#     ID: COVID19_Participant9, Label: 1
#     ID: Control_Participant1, Label: 0
#     ID: Control_Participant10, Label: 0
#     ID: Control_Participant11, Label: 0
#     ID: Control_Participant12, Label: 0
#     ID: Control_Participant13, Label: 0
#     ID: Control_Participant15, Label: 0
#     ID: Control_Participant2, Label: 0
#     ID: Control_Participant3, Label: 0
#     ID: Control_Participant4, Label: 0
#     ID: Control_Participant5, Label: 0
#     ID: Control_Participant6, Label: 0
#     ID: Control_Participant8, Label: 0
#   → test 환자 ID 및 라벨:
#     ID: COVID19_Participant11, Label: 1
#     ID: COVID19_Participant18, Label: 1
#     ID: COVID19_Participant25, Label: 1
#     ID: COVID19_Participant28, Label: 1
#     ID: COVID19_Participant30, Label: 1
#     ID: COVID19_Participant39, Label: 1
#     ID: COVID19_Participant8, Label: 1
#     ID: Control_Participant14, Label: 0
#     ID: Control_Participant7, Label: 0
#     ID: Control_Participant9, Label: 0
